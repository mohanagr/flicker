# %%
from matplotlib import pyplot as plt
import numpy as np
from scipy.optimize import least_squares

# %%
def average_rows(x,nblock=100):
    nr=x.shape[0]//nblock
    nc=x.shape[1]
    y=np.zeros((nr,nc),dtype=x.dtype)
    for i in range(nr):
        y[i,:]=np.mean(x[i*nblock:(i+1)*nblock],axis=0)
    return y

# %%
def get_coarse_xcorr(f1,f2,chans=None):
    """ Get coarse xcorr of each channel of two channelized timestreams.
    The xcorr is 0-padded, so length of output is twice the original length (shape[0]).
    
    Parameters
    ----------
    f1, f2 : ndarray of complex64
        First and second timestreams. Both n_spectrum x n_channel complex array.
    chans: tuple of int
        Channels (columns) of f1 and f2 that should be correlated.
    
    Returns
    -------
    ndarray of complex128
        xcorr of each channel's timestream. 2*n_spectrum x n_channel complex array.
    """
    Nsmall=f1.shape[0]
    print("Shape of passed channelized timestream =", f1.shape)
    if chans is None:
        chans = np.arange(f1.shape[1])
    xcorr=np.zeros((len(chans),2*Nsmall),dtype='complex128')
    win=np.hamming(2*Nsmall)
    wt = np.zeros(2*Nsmall)
    wt[:Nsmall] = 1
    n_avg = np.fft.irfft(np.fft.rfft(wt)*np.conj(np.fft.rfft(wt)))
    print(n_avg)
    for i,chan in enumerate(chans):
        print("processing chan", chan)
        xcorr[i, :] = np.fft.ifft(
                        np.fft.fft(np.hstack([f1[:, chan].flatten(), np.zeros(Nsmall, dtype="complex128")]))
                        * np.conj(
                            np.fft.fft(np.hstack([f2[:, chan].flatten(), np.zeros(Nsmall, dtype="complex128")]))
                        )
                    )
        xcorr[i, :]=xcorr[i, :]/n_avg
    print(xcorr.shape)
    return np.ma.masked_invalid(xcorr)

@nb.njit(parallel=True,cache=True)
def make_complex(cmpl,mag,phase):
    N=cmpl.shape[0]
    for i in nb.prange(0,N):
        cmpl[i] = mag[i]*np.exp(1J*phase[i])

def get_interp_xcorr(coarse_xcorr, freq, sample_no, coarse_sample_no, offset, osamp=1):
    print("coarse shape", coarse_xcorr.shape)
    t1=time.time()
    final_xcorr_cwave = np.empty((coarse_xcorr.shape[0]-1)*8192*osamp,dtype='complex128')
    print("Total upsampled timestream samples in this coarse chunk =",sample_no.shape)
    t2=time.time()
    print("generation",t2-t1)
    sample_no2 = sample_no + offset
    t1=time.time()
    uph=np.unwrap(np.angle(coarse_xcorr))
    t2=time.time()
    print("unwrap",t2-t1)
    newphase=2*np.pi*freq*np.arange(0,coarse_xcorr.shape[0])+uph
    t1=time.time()
    newphase=np.interp(sample_no,coarse_sample_no,newphase)
    t2=time.time()
    print("interp", t2-t1)
    t1=time.time()
    cs=CubicSpline(coarse_sample_no,np.abs(coarse_xcorr))
    t2=time.time()
    print("CS gen", t2-t1)
    t1=time.time()
    newmag=cs(sample_no2)
    t2=time.time()
    print("cs eval",t2-t1)
    t1=time.time()
    
    t1=time.time()
    make_complex(final_xcorr_cwave,newmag,newphase)
    t2=time.time()
    print("make complex",t2-t1)
    # newmag = np.interp(x,np.arange(0,len(y))*4096,np.abs(c1full))
    return final_xcorr_cwave
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 39
#      36     print(xcorr.shape)
#      37     return np.ma.masked_invalid(xcorr)
# ---> 39 @nb.njit(parallel=True,cache=True)
#      40 def make_complex(cmpl,mag,phase):
#      41     N=cmpl.shape[0]
#      42     for i in nb.prange(0,N):
#
# NameError: name 'nb' is not defined

# %%
def get_adev(x,tau,stidx=0,endidx=None):
    dt=4096/250e6
    delta=int(tau/dt)
#     print(delta)
    sl=slice(stidx,endidx,delta)
    samps=x[sl]
#     print(samps)
    adev=np.sqrt(np.mean((samps[2:]-2*samps[1:-1]+samps[:-2])**2)/(2*tau**2))
    return adev

# %%
with np.load("../spectra_1830_1840_4096_clock_low_noise.npz") as f:
    spec1=f['spectra1']
    spec2=f['spectra2']
    delays=f['delays']

# %%
spec1.shape, spec2.shape
# Out:
# ((50000, 10), (50000, 10))

# %%
50000*16e-6
# Out:
# 0.7999999999999999

# %%
taus=10**np.linspace(-3,0,101)
# taus=np.linspace(0.1,2,1001)
adevs=np.zeros(len(taus))
for i,tau in enumerate(taus):
    adevs[i]=get_adev(delays,tau)

# %%
plt.loglog(taus,adevs*4e-9,label='adev of sim noise')
# params=np.polyfit(np.log10(taus), np.log10(adevs),2)
# plt.loglog(taus,10**np.polyval(params,np.log10(taus))*4e-9,label='quadratic fit')
plt.legend()
#4 to 5 OOM worse than actual LB ADEV.

# %%
6e-7*1e-2/4e-9 #rough error in number of samples tau * adev(tau), for about 1000 spectra.
# Out:
# 1.5

# %%
st=1000
en=1300
plt.plot(delays[st:en])
m,c=np.polyfit(np.arange(st,en),delays[st:en],1)
# m,c=np.polyfit(np.arange(0,en-st),delays[st:en]-delays[st],1)
print(m,c)
# plt.xlim(20000,50000)
# Out:
# -0.0016897008794514582 -0.52891039535232

# %%
#resolution with 500 fft size is
1/500 * (4096/1834)
# Out:
# 0.004466739367502727

# %%
def newton(n,xc,alpha,chan,scale=1):
    c=2*np.pi*chan/4096
    N=len(xc)
    xc_phased = xc*np.exp(1j*c*n*alpha)
    S0conj=np.conj(np.mean(xc_phased))
    S1=np.mean(xc_phased*n*c)
    S2=np.mean(xc_phased*n**2*c**2)
    df=np.imag(S0conj*S1)
    ddf=np.real(S0conj*S2) - np.abs(S1)**2
    alpha2 = alpha - scale*df/ddf
    print(f"old alpha {alpha:5.3e}, df {df:5.3e}, ddf {ddf:5.3e}, step size {df/ddf:5.3e} new alpha {alpha2:5.3e} ")
    return alpha2

def solver(xc,alpha,chan,scale=1,atol=1e-10,rtol=1e-6):
    niter=10
    success=0
    N=len(xc)
    n = np.arange(N)
    for i in range(niter):
        alpha2=newton(n,xc,alpha,chan,scale=scale)
        if np.abs(alpha2) < atol:
            print("atol hit")
            success=1
            break
        if np.abs((alpha2-alpha)/alpha) < rtol:
            print("rtol hit")
            success=1
            break
        alpha=alpha2
    if not success:
        print("Max iterations, unsuccessful.")
    return alpha2

# %%
def objective_func(xc,alpha,chan):
    c=2*np.pi*chan/4096
    N=len(xc)
    n=np.arange(N)
    xc_phased = xc*np.exp(1j*c*n*alpha)
    return np.abs(np.mean(xc_phased))**2

# %%
y1=spec1[st:en,4]
y2=spec2[st:en,4]
xc_small = y1*np.conj(y2)
print(np.mean(xc_small))
xc_small = xc_small #* np.exp(-1j*np.angle(xc_small)[0]) #a constant phase offset is not what we care about
# print(np.angle(xc_small))
np.mean(xc_small)
#whether or not FFT will be useful depends on whether we can resolve the slow sine wave across the chunk being FFT'ed.
# Out:
# (-0.04664640198188927+0.028295910582347764j)
# np.complex128(-0.04664640198188927+0.028295910582347764j)

# %%
#take an fft to see which value to try.
xc_fft = np.fft.fftshift(np.abs(np.fft.fft(xc_small))) # should peak at -ve freq cause deltat is 2.5e-4, and fft is exp(-jomega t)
mm=np.argmax(xc_fft)
plt.plot(xc_fft)
plt.xlim(mm-100,mm+100)
M=len(xc_fft)
print(M)
print("Max at", mm-len(xc_fft)/2)
expected_delta = (mm-M/2)/M * (4096/1834)
print("Expected delta=", expected_delta)
# Out:
# 10000
# Max at 58.0
# Expected delta= 0.012953544165757907

# %%
alphas=np.linspace(-2e-2,2e-2,101)
f_alpha = np.zeros(len(alphas))
for i in range(len(f_alpha)):
    f_alpha[i] = objective_func(xc_small,alphas[i],1834)
plt.plot(alphas,f_alpha)

# %%
alpha=expected_delta
solver(xc_small,alpha,1834,rtol=1e-4)
# Out:
# old alpha 1.340e-02, df 8.507e+00, ddf 1.701e+04, step size 5.003e-04 new alpha 1.290e-02
# old alpha 1.290e-02, df -3.560e+00, ddf 3.105e+04, step size -1.147e-04 new alpha 1.301e-02
# old alpha 1.301e-02, df -1.730e-01, ddf 2.799e+04, step size -6.181e-06 new alpha 1.302e-02
# old alpha 1.302e-02, df -5.265e-04, ddf 2.782e+04, step size -1.893e-08 new alpha 1.302e-02
# rtol hit
# np.float64(0.01302083073517558)

# %%
m,c=np.polyfit(np.arange(2500,7500),delays[2500:7500],1)
y=delays[2500:7500]
y-=y[0]
yp=m*np.arange(2500,7500)+c
yp-=yp[0]
print(m,c)
plt.plot(y)
plt.plot(yp)
plt.plot(-1.295e-2*np.arange(0,5000))
# Out:
# -0.01212472255697502 33.11992819722041

# %%
#iterate over several blocks and fit a line
blocksize=1000
st=5000
nblocks=100
en=blocksize*nblocks
fit_delta=np.zeros(nblocks,dtype='float64')
actual_delta = np.zeros(nblocks,dtype='float64')
for i in range(nblocks):
    #fft and get a coarse guess
    ix=st+i*blocksize
    y1=spec1[ix:ix+blocksize,4]
    y2=spec2[ix:ix+blocksize,4]
    xc_small = y1*np.conj(y2)
    xc_fft = np.fft.fftshift(np.abs(np.fft.fft(xc_small)))

    mm=np.argmax(xc_fft)
    # plt.plot(xc_fft)
    # plt.xlim(mm-100,mm+100)
    M=len(xc_fft)
    # print(M)
    # print("Max at", mm-len(xc_fft)/2)
    expected_delta = (mm-M/2)/M * (4096/1834)
    # print(f"Block {i} Expected delta={expected_delta}")
    alpha=solver(xc_small,expected_delta,1834,rtol=1e-4)
    fit_delta[i]=alpha
    # plt.title(f"Block {i}")
    # plt.plot(delays[ix:ix+blocksize])
    # plt.show()

    m,c=np.polyfit(np.arange(ix,ix+blocksize),delays[ix:ix+blocksize],1)
    # m,c=np.polyfit(np.arange(0,en-st),delays[st:en]-delays[st],1)
    print(f"block {i} slope", m, "pred slope", -alpha)
    actual_delta[i] = m
# Out:
# old alpha 1.340e-02, df 1.826e+01, ddf 6.822e+04, step size 2.676e-04 new alpha 1.313e-02
# old alpha 1.313e-02, df -4.734e+00, ddf 1.010e+05, step size -4.689e-05 new alpha 1.318e-02
# old alpha 1.318e-02, df -1.005e-01, ddf 9.654e+04, step size -1.042e-06 new alpha 1.318e-02
# rtol hit
# block 0 slope -0.012766087451217363 pred slope -0.013180515994224873
# old alpha 1.340e-02, df -2.759e+01, ddf -5.008e+04, step size 5.509e-04 new alpha 1.285e-02
# old alpha 1.285e-02, df -2.080e+01, ddf 1.701e+04, step size -1.223e-03 new alpha 1.407e-02
# old alpha 1.407e-02, df -6.514e+01, ddf -1.441e+04, step size 4.520e-03 new alpha 9.553e-03
# old alpha 9.553e-03, df -3.592e+01, ddf -3.464e+04, step size 1.037e-03 new alpha 8.516e-03
# old alpha 8.516e-03, df -8.275e+00, ddf 6.075e+03, step size -1.362e-03 new alpha 9.878e-03
# old alpha 9.878e-03, df -3.927e+01, ddf 1.903e+04, step size -2.063e-03 new alpha 1.194e-02
# old alpha 1.194e-02, df -4.537e+00, ddf -7.839e+04, step size 5.787e-05 new alpha 1.188e-02
# old alpha 1.188e-02, df 1.544e-01, ddf -8.348e+04, step size -1.850e-06 new alpha 1.189e-02
# old alpha 1.189e-02, df 1.285e-04, ddf -8.334e+04, step size -1.541e-09 new alpha 1.189e-02
# rtol hit
# block 1 slope -0.013265901788769211 pred slope -0.011885421681383176
# old alpha 1.563e-02, df 7.768e+00, ddf 3.842e+04, step size 2.022e-04 new alpha 1.543e-02
# old alpha 1.543e-02, df -8.472e-02, ddf 3.824e+04, step size -2.216e-06 new alpha 1.543e-02
# old alpha 1.543e-02, df 3.773e-05, ddf 3.827e+04, step size 9.858e-10 new alpha 1.543e-02
# rtol hit
# block 2 slope -0.02295404773871505 pred slope -0.015433618124820928
# old alpha 1.787e-02, df -5.613e-01, ddf 4.226e+04, step size -1.328e-05 new alpha 1.788e-02
# old alpha 1.788e-02, df 6.040e-04, ddf 4.235e+04, step size 1.426e-08 new alpha 1.788e-02
# rtol hit
# block 3 slope -0.014456191292844835 pred slope -0.01788022510161532
# old alpha 1.117e-02, df -5.745e+01, ddf -1.281e+05, step size 4.486e-04 new alpha 1.072e-02
# old alpha 1.072e-02, df -1.470e+01, ddf -5.074e+04, step size 2.897e-04 new alpha 1.043e-02
# old alpha 1.043e-02, df -8.993e+00, ddf 8.357e+03, step size -1.076e-03 new alpha 1.150e-02
# old alpha 1.150e-02, df -1.001e+02, ddf -1.098e+05, step size 9.113e-04 new alpha 1.059e-02
# old alpha 1.059e-02, df -1.010e+01, ddf -2.314e+04, step size 4.365e-04 new alpha 1.016e-02
# old alpha 1.016e-02, df -1.586e+01, ddf 3.634e+04, step size -4.365e-04 new alpha 1.059e-02
# old alpha 1.059e-02, df -1.010e+01, ddf -2.315e+04, step size 4.364e-04 new alpha 1.016e-02
# old alpha 1.016e-02, df -1.586e+01, ddf 3.634e+04, step size -4.365e-04 new alpha 1.059e-02
# old alpha 1.059e-02, df -1.010e+01, ddf -2.316e+04, step size 4.363e-04 new alpha 1.016e-02
# old alpha 1.016e-02, df -1.585e+01, ddf 3.633e+04, step size -4.364e-04 new alpha 1.059e-02
# Max iterations, unsuccessful.
# block 4 slope -0.010929178076995599 pred slope -0.010593446383258936
# old alpha 6.700e-03, df -1.430e+02, ddf 1.050e+05, step size -1.363e-03 new alpha 8.063e-03
# old alpha 8.063e-03, df 1.057e+02, ddf -1.416e+04, step size -7.463e-03 new alpha 1.553e-02
# old alpha 1.553e-02, df -5.135e+01, ddf -1.067e+04, step size 4.814e-03 new alpha 1.071e-02
# old alpha 1.071e-02, df 1.656e+01, ddf 6.576e+04, step size 2.519e-04 new alpha 1.046e-02
# old alpha 1.046e-02, df -1.800e+00, ddf 7.860e+04, step size -2.290e-05 new alpha 1.048e-02
# old alpha 1.048e-02, df -8.586e-03, ddf 7.783e+04, step size -1.103e-07 new alpha 1.048e-02
# rtol hit
# block 5 slope -0.010181988830905816 pred slope -0.010482706895356407
# old alpha 8.933e-03, df -4.615e+01, ddf 1.636e+05, step size -2.820e-04 new alpha 9.215e-03
# old alpha 9.215e-03, df 5.842e+00, ddf 1.940e+05, step size 3.012e-05 new alpha 9.185e-03
# old alpha 9.185e-03, df -2.315e-03, ddf 1.940e+05, step size -1.193e-08 new alpha 9.185e-03
# rtol hit
# block 6 slope -0.011549890697084635 pred slope -0.009185382704363539
# old alpha 8.933e-03, df -9.674e+01, ddf -2.008e+05, step size 4.818e-04 new alpha 8.452e-03
# old alpha 8.452e-03, df 2.503e+01, ddf -2.666e+05, step size -9.388e-05 new alpha 8.546e-03
# old alpha 8.546e-03, df -3.152e-01, ddf -2.719e+05, step size 1.159e-06 new alpha 8.544e-03
# old alpha 8.544e-03, df -6.893e-06, ddf -2.719e+05, step size 2.536e-11 new alpha 8.544e-03
# rtol hit
# block 7 slope -0.010261919919355107 pred slope -0.00854439874664645
# old alpha 4.467e-03, df 3.335e+02, ddf 2.712e+05, step size 1.230e-03 new alpha 3.237e-03
# old alpha 3.237e-03, df -3.353e+02, ddf 1.712e+05, step size -1.959e-03 new alpha 5.196e-03
# old alpha 5.196e-03, df 1.841e+02, ddf -5.656e+05, step size -3.254e-04 new alpha 5.521e-03
# old alpha 5.521e-03, df -8.583e+00, ddf -5.701e+05, step size 1.505e-05 new alpha 5.506e-03
# old alpha 5.506e-03, df 4.608e-02, ddf -5.761e+05, step size -7.997e-08 new alpha 5.506e-03
# rtol hit
# block 8 slope -0.004317948800893173 pred slope -0.005506361324360974
# old alpha 2.233e-03, df 3.842e+01, ddf -2.831e+05, step size -1.357e-04 new alpha 2.369e-03
# old alpha 2.369e-03, df 2.132e+00, ddf -2.494e+05, step size -8.550e-06 new alpha 2.378e-03
# old alpha 2.378e-03, df 1.096e-02, ddf -2.468e+05, step size -4.439e-08 new alpha 2.378e-03
# rtol hit
# block 9 slope -0.004057796181418092 pred slope -0.0023776401003103107
# old alpha -6.298e-01, df 8.407e+01, ddf -9.046e+04, step size -9.294e-04 new alpha -6.289e-01
# old alpha -6.289e-01, df -1.735e+00, ddf -6.926e+04, step size 2.505e-05 new alpha -6.289e-01
# rtol hit
# block 10 slope -0.004887599172689483 pred slope 0.6289059332908107
# old alpha 2.233e-03, df 6.318e+01, ddf 1.184e+05, step size 5.334e-04 new alpha 1.700e-03
# old alpha 1.700e-03, df -5.903e+00, ddf 9.873e+04, step size -5.979e-05 new alpha 1.760e-03
# old alpha 1.760e-03, df 4.498e-01, ddf 1.133e+05, step size 3.969e-06 new alpha 1.756e-03
# old alpha 1.756e-03, df 1.744e-03, ddf 1.124e+05, step size 1.551e-08 new alpha 1.756e-03
# rtol hit
# block 11 slope -0.0033075661603002697 pred slope -0.0017557262585928331
# old alpha 8.933e-03, df 6.223e-01, ddf -4.425e+04, step size -1.406e-05 new alpha 8.948e-03
# old alpha 8.948e-03, df 2.329e-02, ddf -4.095e+04, step size -5.688e-07 new alpha 8.948e-03
# rtol hit
# block 12 slope -0.009225705494253602 pred slope -0.008948110778189106
# old alpha 8.933e-03, df 2.333e+01, ddf 1.238e+05, step size 1.885e-04 new alpha 8.745e-03
# old alpha 8.745e-03, df -5.929e+00, ddf 1.824e+05, step size -3.250e-05 new alpha 8.777e-03
# old alpha 8.777e-03, df -1.301e-01, ddf 1.743e+05, step size -7.467e-07 new alpha 8.778e-03
# rtol hit
# block 13 slope -0.005208793042540194 pred slope -0.008778245736944414
# old alpha 4.467e-03, df 1.480e+01, ddf 7.451e+04, step size 1.987e-04 new alpha 4.268e-03
# old alpha 4.268e-03, df 3.965e-01, ddf 6.879e+04, step size 5.764e-06 new alpha 4.262e-03
# old alpha 4.262e-03, df 9.105e-04, ddf 6.848e+04, step size 1.330e-08 new alpha 4.262e-03
# rtol hit
# block 14 slope -0.00656235565917587 pred slope -0.0042622867426852905
# old alpha 2.233e-03, df 2.441e+02, ddf 4.335e+05, step size 5.631e-04 new alpha 1.670e-03
# old alpha 1.670e-03, df -5.516e+01, ddf 5.232e+05, step size -1.054e-04 new alpha 1.776e-03
# old alpha 1.776e-03, df 1.862e+00, ddf 5.550e+05, step size 3.355e-06 new alpha 1.772e-03
# old alpha 1.772e-03, df 1.137e-03, ddf 5.543e+05, step size 2.052e-09 new alpha 1.772e-03
# rtol hit
# block 15 slope -0.005343447114353504 pred slope -0.0017723256009020236
# old alpha 6.700e-03, df 3.263e+01, ddf -1.199e+05, step size -2.723e-04 new alpha 6.972e-03
# old alpha 6.972e-03, df -2.642e+00, ddf -1.289e+05, step size 2.049e-05 new alpha 6.952e-03
# old alpha 6.952e-03, df 1.575e-02, ddf -1.304e+05, step size -1.208e-07 new alpha 6.952e-03
# rtol hit
# block 16 slope -0.006844979460730386 pred slope -0.006952005376474467
# old alpha 0.000e+00, df 2.660e+02, ddf -1.940e+05, step size -1.371e-03 new alpha 1.371e-03
# old alpha 1.371e-03, df 4.917e+01, ddf 4.164e+03, step size 1.181e-02 new alpha -1.044e-02
# old alpha -1.044e-02, df -1.165e+02, ddf -1.093e+05, step size 1.066e-03 new alpha -1.150e-02
# old alpha -1.150e-02, df 2.583e+01, ddf -3.820e+03, step size -6.760e-03 new alpha -4.742e-03
# old alpha -4.742e-03, df -1.194e+02, ddf 5.258e+05, step size -2.270e-04 new alpha -4.515e-03
# old alpha -4.515e-03, df 1.674e+01, ddf 6.464e+05, step size 2.589e-05 new alpha -4.541e-03
# old alpha -4.541e-03, df 6.401e-02, ddf 6.411e+05, step size 9.984e-08 new alpha -4.541e-03
# rtol hit
# block 17 slope -0.0011438791237553016 pred slope 0.004540990515898856
# old alpha 0.000e+00, df 3.996e+02, ddf 4.571e+05, step size 8.742e-04 new alpha -8.742e-04
# old alpha -8.742e-04, df -2.764e+02, ddf 8.214e+05, step size -3.365e-04 new alpha -5.377e-04
# old alpha -5.377e-04, df 1.729e+01, ddf 8.787e+05, step size 1.968e-05 new alpha -5.573e-04
# old alpha -5.573e-04, df -4.298e-02, ddf 8.829e+05, step size -4.868e-08 new alpha -5.573e-04
# rtol hit
# block 18 slope 0.0022629154977008743 pred slope 0.0005572897962101631
# old alpha 4.467e-03, df 3.453e+01, ddf 9.955e+04, step size 3.468e-04 new alpha 4.120e-03
# old alpha 4.120e-03, df -7.792e+00, ddf 1.349e+05, step size -5.776e-05 new alpha 4.178e-03
# old alpha 4.178e-03, df -3.684e-02, ddf 1.333e+05, step size -2.764e-07 new alpha 4.178e-03
# rtol hit
# block 19 slope -0.004798085091432566 pred slope -0.004177963719311248
# old alpha 2.233e-03, df 3.107e+02, ddf 5.655e+04, step size 5.495e-03 new alpha -3.261e-03
# old alpha -3.261e-03, df 8.156e+00, ddf -4.892e+05, step size -1.667e-05 new alpha -3.245e-03
# old alpha -3.245e-03, df -4.278e-02, ddf -4.942e+05, step size 8.657e-08 new alpha -3.245e-03
# rtol hit
# block 20 slope -0.004479715043872809 pred slope 0.0032448874886966553
# old alpha 2.233e-03, df -1.071e+02, ddf -7.737e+04, step size 1.385e-03 new alpha 8.486e-04
# old alpha 8.486e-04, df 1.299e+02, ddf -7.397e+04, step size -1.757e-03 new alpha 2.605e-03
# old alpha 2.605e-03, df -1.254e+02, ddf -3.387e+04, step size 3.702e-03 new alpha -1.097e-03
# old alpha -1.097e-03, df 2.148e+02, ddf -1.300e+05, step size -1.652e-03 new alpha 5.550e-04
# old alpha 5.550e-04, df 1.342e+02, ddf 4.018e+04, step size 3.340e-03 new alpha -2.785e-03
# old alpha -2.785e-03, df -4.708e+02, ddf 1.379e+05, step size -3.413e-03 new alpha 6.277e-04
# old alpha 6.277e-04, df 1.362e+02, ddf 1.513e+04, step size 9.003e-03 new alpha -8.376e-03
# old alpha -8.376e-03, df -1.680e+02, ddf -2.675e+05, step size 6.282e-04 new alpha -9.004e-03
# old alpha -9.004e-03, df 3.344e+01, ddf -2.793e+05, step size -1.197e-04 new alpha -8.884e-03
# old alpha -8.884e-03, df -2.755e+00, ddf -3.220e+05, step size 8.556e-06 new alpha -8.893e-03
# Max iterations, unsuccessful.
# block 21 slope -0.0020539434007482292 pred slope 0.008892591125901744
# old alpha 2.233e-03, df -1.890e+02, ddf -1.949e+05, step size 9.694e-04 new alpha 1.264e-03
# old alpha 1.264e-03, df 1.928e+02, ddf -3.504e+05, step size -5.502e-04 new alpha 1.814e-03
# old alpha 1.814e-03, df -4.578e+01, ddf -4.451e+05, step size 1.029e-04 new alpha 1.711e-03
# old alpha 1.711e-03, df 1.064e+00, ddf -4.626e+05, step size -2.300e-06 new alpha 1.714e-03
# old alpha 1.714e-03, df 2.178e-04, ddf -4.625e+05, step size -4.711e-10 new alpha 1.714e-03
# rtol hit
# block 22 slope -0.0018341578479260333 pred slope -0.0017136394369785923
# old alpha 0.000e+00, df 9.579e+02, ddf 3.995e+05, step size 2.398e-03 new alpha -2.398e-03
# old alpha -2.398e-03, df -6.126e+02, ddf -1.031e+06, step size 5.942e-04 new alpha -2.992e-03
# old alpha -2.992e-03, df -8.179e+01, ddf -5.889e+05, step size 1.389e-04 new alpha -3.131e-03
# old alpha -3.131e-03, df -1.345e+01, ddf -3.950e+05, step size 3.406e-05 new alpha -3.165e-03
# old alpha -3.165e-03, df -8.021e-01, ddf -3.480e+05, step size 2.305e-06 new alpha -3.167e-03
# old alpha -3.167e-03, df -3.634e-03, ddf -3.448e+05, step size 1.054e-08 new alpha -3.167e-03
# rtol hit
# block 23 slope -0.000683029863895406 pred slope 0.0031674064192562337
# old alpha 6.700e-03, df -1.734e+01, ddf -2.649e+04, step size 6.547e-04 new alpha 6.045e-03
# old alpha 6.045e-03, df 5.735e+01, ddf -2.047e+05, step size -2.802e-04 new alpha 6.326e-03
# old alpha 6.326e-03, df 1.034e+01, ddf -1.273e+05, step size -8.121e-05 new alpha 6.407e-03
# old alpha 6.407e-03, df 9.932e-01, ddf -1.029e+05, step size -9.650e-06 new alpha 6.416e-03
# old alpha 6.416e-03, df 1.382e-02, ddf -1.001e+05, step size -1.381e-07 new alpha 6.417e-03
# rtol hit
# block 24 slope -0.006047464508923058 pred slope -0.006416594554650423
# old alpha -7.169e-01, df 3.986e+01, ddf -1.220e+05, step size -3.266e-04 new alpha -7.166e-01
# old alpha -7.166e-01, df -2.376e+00, ddf -1.239e+05, step size 1.917e-05 new alpha -7.166e-01
# rtol hit
# block 25 slope -0.005902721746174303 pred slope 0.7166042118930974
# old alpha 4.467e-03, df 4.271e+00, ddf -1.042e+05, step size -4.098e-05 new alpha 4.508e-03
# old alpha 4.508e-03, df -1.815e-01, ddf -1.130e+05, step size 1.606e-06 new alpha 4.506e-03
# old alpha 4.506e-03, df -2.674e-04, ddf -1.127e+05, step size 2.373e-09 new alpha 4.506e-03
# rtol hit
# block 26 slope -0.00406636570615073 pred slope -0.004506106448627999
# old alpha 8.933e-03, df -4.249e+01, ddf 1.681e+05, step size -2.528e-04 new alpha 9.186e-03
# old alpha 9.186e-03, df 2.834e+00, ddf 1.839e+05, step size 1.542e-05 new alpha 9.171e-03
# old alpha 9.171e-03, df -1.494e-03, ddf 1.840e+05, step size -8.117e-09 new alpha 9.171e-03
# rtol hit
# block 27 slope -0.007317915423959899 pred slope -0.009170855430439597
# old alpha 2.233e-03, df 2.576e+01, ddf -2.709e+05, step size -9.508e-05 new alpha 2.328e-03
# old alpha 2.328e-03, df 1.996e+00, ddf -2.282e+05, step size -8.749e-06 new alpha 2.337e-03
# old alpha 2.337e-03, df 1.815e-02, ddf -2.240e+05, step size -8.101e-08 new alpha 2.337e-03
# rtol hit
# block 28 slope -0.0028891866994616407 pred slope -0.0023372791140738474
# old alpha 2.233e-03, df 1.226e+02, ddf 3.114e+05, step size 3.938e-04 new alpha 1.840e-03
# old alpha 1.840e-03, df 1.246e+01, ddf 2.253e+05, step size 5.528e-05 new alpha 1.784e-03
# old alpha 1.784e-03, df 5.620e-01, ddf 2.049e+05, step size 2.744e-06 new alpha 1.782e-03
# old alpha 1.782e-03, df 1.423e-03, ddf 2.038e+05, step size 6.980e-09 new alpha 1.781e-03
# rtol hit
# block 29 slope 9.287395090115154e-05 pred slope -0.0017814991240550357
# old alpha 2.233e-03, df -1.524e+02, ddf 6.676e+04, step size -2.284e-03 new alpha 4.517e-03
# old alpha 4.517e-03, df -3.298e+01, ddf -5.705e+04, step size 5.780e-04 new alpha 3.939e-03
# old alpha 3.939e-03, df 6.066e+01, ddf -2.159e+05, step size -2.810e-04 new alpha 4.220e-03
# old alpha 4.220e-03, df 2.944e+00, ddf -1.775e+05, step size -1.659e-05 new alpha 4.236e-03
# old alpha 4.236e-03, df 4.300e-02, ddf -1.723e+05, step size -2.496e-07 new alpha 4.237e-03
# rtol hit
# block 30 slope -0.0026992242908349937 pred slope -0.00423674890292832
# old alpha 2.233e-03, df -1.011e+02, ddf 1.025e+04, step size -9.855e-03 new alpha 1.209e-02
# old alpha 1.209e-02, df 1.400e+01, ddf 1.284e+05, step size 1.090e-04 new alpha 1.198e-02
# old alpha 1.198e-02, df -6.272e-01, ddf 1.389e+05, step size -4.517e-06 new alpha 1.198e-02
# old alpha 1.198e-02, df -6.731e-04, ddf 1.386e+05, step size -4.858e-09 new alpha 1.198e-02
# rtol hit
# block 31 slope -0.0024378359045081873 pred slope -0.011983869909069463
# old alpha -2.233e-03, df 6.289e+01, ddf -1.822e+05, step size -3.451e-04 new alpha -1.888e-03
# old alpha -1.888e-03, df -2.469e+01, ddf -3.070e+05, step size 8.044e-05 new alpha -1.969e-03
# old alpha -1.969e-03, df -6.901e-01, ddf -2.885e+05, step size 2.392e-06 new alpha -1.971e-03
# old alpha -1.971e-03, df -7.957e-04, ddf -2.879e+05, step size 2.764e-09 new alpha -1.971e-03
# rtol hit
# block 32 slope 0.0023147309865613774 pred slope 0.001971114496536848
# old alpha 0.000e+00, df -9.769e+00, ddf 6.637e+05, step size -1.472e-05 new alpha 1.472e-05
# old alpha 1.472e-05, df -5.838e-03, ddf 6.629e+05, step size -8.808e-09 new alpha 1.473e-05
# old alpha 1.473e-05, df -2.768e-09, ddf 6.629e+05, step size -4.175e-15 new alpha 1.473e-05
# rtol hit
# block 33 slope 0.00014312626426356729 pred slope -1.472661487975973e-05
# old alpha 2.233e-03, df 6.718e+01, ddf -1.097e+05, step size -6.123e-04 new alpha 2.846e-03
# old alpha 2.846e-03, df 1.903e+01, ddf -5.398e+04, step size -3.526e-04 new alpha 3.198e-03
# old alpha 3.198e-03, df 3.539e+00, ddf -3.396e+04, step size -1.042e-04 new alpha 3.302e-03
# old alpha 3.302e-03, df 3.343e-01, ddf -2.744e+04, step size -1.219e-05 new alpha 3.315e-03
# old alpha 3.315e-03, df 4.899e-03, ddf -2.663e+04, step size -1.840e-07 new alpha 3.315e-03
# rtol hit
# block 34 slope -0.0017459827810188267 pred slope -0.003314838182378609
# old alpha 2.881e-01, df 2.972e+00, ddf -1.442e+04, step size -2.061e-04 new alpha 2.883e-01
# old alpha 2.883e-01, df 8.884e-01, ddf -6.015e+03, step size -1.477e-04 new alpha 2.885e-01
# old alpha 2.885e-01, df 3.678e-01, ddf -1.282e+03, step size -2.870e-04 new alpha 2.887e-01
# old alpha 2.887e-01, df 7.596e-01, ddf 2.759e+03, step size 2.753e-04 new alpha 2.885e-01
# old alpha 2.885e-01, df 3.546e-01, ddf -9.745e+02, step size -3.639e-04 new alpha 2.888e-01
# old alpha 2.888e-01, df 9.964e-01, ddf 2.464e+03, step size 4.044e-04 new alpha 2.884e-01
# old alpha 2.884e-01, df 4.161e-01, ddf -2.083e+03, step size -1.998e-04 new alpha 2.886e-01
# old alpha 2.886e-01, df 4.691e-01, ddf 2.037e+03, step size 2.303e-04 new alpha 2.884e-01
# old alpha 2.884e-01, df 4.936e-01, ddf -3.003e+03, step size -1.644e-04 new alpha 2.886e-01
# old alpha 2.886e-01, df 3.647e-01, ddf 1.065e+03, step size 3.425e-04 new alpha 2.882e-01
# Max iterations, unsuccessful.
# block 35 slope -0.005452912782467026 pred slope -0.2882210947511284
# old alpha 0.000e+00, df -4.490e+02, ddf 9.723e+04, step size -4.618e-03 new alpha 4.618e-03
# old alpha 4.618e-03, df 1.756e+01, ddf -7.730e+04, step size -2.272e-04 new alpha 4.845e-03
# old alpha 4.845e-03, df 2.724e+00, ddf -5.348e+04, step size -5.095e-05 new alpha 4.896e-03
# old alpha 4.896e-03, df 1.309e-01, ddf -4.836e+04, step size -2.708e-06 new alpha 4.898e-03
# old alpha 4.898e-03, df 3.627e-04, ddf -4.809e+04, step size -7.542e-09 new alpha 4.898e-03
# rtol hit
# block 36 slope -0.0028594271329316526 pred slope -0.004898454005169666
# old alpha -2.233e-03, df -3.718e+01, ddf -8.665e+04, step size 4.291e-04 new alpha -2.662e-03
# old alpha -2.662e-03, df 1.099e+01, ddf -1.206e+05, step size -9.107e-05 new alpha -2.571e-03
# old alpha -2.571e-03, df -1.104e-01, ddf -1.223e+05, step size 9.030e-07 new alpha -2.572e-03
# old alpha -2.572e-03, df 3.635e-06, ddf -1.223e+05, step size -2.973e-11 new alpha -2.572e-03
# rtol hit
# block 37 slope 0.0016234245734141836 pred slope 0.0025723024778512914
# old alpha -2.233e-03, df -1.379e+02, ddf -1.374e+05, step size 1.003e-03 new alpha -3.237e-03
# old alpha -3.237e-03, df -1.117e+01, ddf -4.707e+04, step size 2.373e-04 new alpha -3.474e-03
# old alpha -3.474e-03, df 2.059e-01, ddf -5.612e+04, step size -3.669e-06 new alpha -3.470e-03
# old alpha -3.470e-03, df 8.458e-04, ddf -5.566e+04, step size -1.520e-08 new alpha -3.470e-03
# rtol hit
# block 38 slope 0.00180249224121885 pred slope 0.003470340490396771
# old alpha -4.467e-03, df 8.694e+01, ddf 1.954e+05, step size 4.450e-04 new alpha -4.912e-03
# old alpha -4.912e-03, df -2.024e+01, ddf 2.414e+05, step size -8.382e-05 new alpha -4.828e-03
# old alpha -4.828e-03, df 5.477e-01, ddf 2.531e+05, step size 2.164e-06 new alpha -4.830e-03
# old alpha -4.830e-03, df 2.051e-04, ddf 2.529e+05, step size 8.112e-10 new alpha -4.830e-03
# rtol hit
# block 39 slope 0.00494790798224194 pred slope 0.004830071027902918
# old alpha -4.467e-03, df -6.289e+01, ddf -6.056e+04, step size 1.039e-03 new alpha -5.505e-03
# old alpha -5.505e-03, df 5.106e+00, ddf -3.573e+04, step size -1.429e-04 new alpha -5.362e-03
# old alpha -5.362e-03, df -1.036e+00, ddf -4.997e+04, step size 2.074e-05 new alpha -5.383e-03
# old alpha -5.383e-03, df -2.022e-02, ddf -4.801e+04, step size 4.211e-07 new alpha -5.384e-03
# rtol hit
# block 40 slope 0.004309850554572668 pred slope 0.0053835474011273915
# old alpha -8.933e-03, df -4.752e+01, ddf -1.763e+05, step size 2.696e-04 new alpha -9.203e-03
# old alpha -9.203e-03, df -1.838e+00, ddf -1.582e+05, step size 1.162e-05 new alpha -9.215e-03
# old alpha -9.215e-03, df -7.835e-03, ddf -1.568e+05, step size 4.996e-08 new alpha -9.215e-03
# rtol hit
# block 41 slope 0.00586666009494836 pred slope 0.00921469967422837
# old alpha -8.933e-03, df 4.869e+01, ddf -3.757e+04, step size -1.296e-03 new alpha -7.638e-03
# old alpha -7.638e-03, df -3.496e+01, ddf -7.021e+04, step size 4.979e-04 new alpha -8.136e-03
# old alpha -8.136e-03, df 5.478e+00, ddf -7.900e+04, step size -6.934e-05 new alpha -8.066e-03
# old alpha -8.066e-03, df -1.146e-01, ddf -8.214e+04, step size 1.395e-06 new alpha -8.068e-03
# old alpha -8.068e-03, df -3.688e-05, ddf -8.208e+04, step size 4.493e-10 new alpha -8.068e-03
# rtol hit
# block 42 slope 0.0064419793091658045 pred slope 0.008067659035318692
# old alpha -2.233e-03, df -6.453e+01, ddf 4.420e+04, step size -1.460e-03 new alpha -7.733e-04
# old alpha -7.733e-04, df 4.880e+01, ddf -4.370e+04, step size -1.117e-03 new alpha 3.433e-04
# old alpha 3.433e-04, df -1.025e+02, ddf -2.221e+05, step size 4.616e-04 new alpha -1.183e-04
# old alpha -1.183e-04, df -1.828e+01, ddf -1.488e+05, step size 1.228e-04 new alpha -2.411e-04
# old alpha -2.411e-04, df -9.430e-01, ddf -1.335e+05, step size 7.063e-06 new alpha -2.482e-04
# old alpha -2.482e-04, df -3.136e-03, ddf -1.326e+05, step size 2.365e-08 new alpha -2.482e-04
# rtol hit
# block 43 slope 0.0027674366674561145 pred slope 0.0002482292464103488
# old alpha -2.233e-03, df -2.240e+02, ddf -4.297e+05, step size 5.212e-04 new alpha -2.755e-03
# old alpha -2.755e-03, df -3.680e+01, ddf -1.911e+05, step size 1.926e-04 new alpha -2.947e-03
# old alpha -2.947e-03, df -1.719e+01, ddf -1.197e+04, step size 1.436e-03 new alpha -4.383e-03
# old alpha -4.383e-03, df -2.093e+02, ddf -1.748e+05, step size 1.197e-03 new alpha -5.581e-03
# old alpha -5.581e-03, df 1.844e+01, ddf 3.172e+03, step size 5.813e-03 new alpha -1.139e-02
# old alpha -1.139e-02, df -1.810e+00, ddf 7.970e+04, step size -2.271e-05 new alpha -1.137e-02
# old alpha -1.137e-02, df 1.129e-02, ddf 8.063e+04, step size 1.400e-07 new alpha -1.137e-02
# rtol hit
# block 44 slope -0.0012358068644912328 pred slope 0.011370951240230465
# old alpha -4.467e-03, df 1.732e+01, ddf -2.403e+04, step size -7.207e-04 new alpha -3.746e-03
# old alpha -3.746e-03, df 1.303e+01, ddf -8.222e+03, step size -1.585e-03 new alpha -2.161e-03
# old alpha -2.161e-03, df -6.053e+00, ddf -3.141e+04, step size 1.927e-04 new alpha -2.354e-03
# old alpha -2.354e-03, df -2.490e+00, ddf -8.078e+03, step size 3.082e-04 new alpha -2.662e-03
# old alpha -2.662e-03, df -2.050e+00, ddf -7.340e+01, step size 2.793e-02 new alpha -3.059e-02
# old alpha -3.059e-02, df -6.925e+01, ddf 3.947e+05, step size -1.754e-04 new alpha -3.042e-02
# old alpha -3.042e-02, df 1.273e+00, ddf 4.007e+05, step size 3.176e-06 new alpha -3.042e-02
# old alpha -3.042e-02, df -5.550e-04, ddf 4.010e+05, step size -1.384e-09 new alpha -3.042e-02
# rtol hit
# block 45 slope 0.00341358298343029 pred slope 0.030418239972964542
# old alpha -2.233e-03, df -5.651e+01, ddf -1.950e+05, step size 2.898e-04 new alpha -2.523e-03
# old alpha -2.523e-03, df 1.740e+01, ddf -2.993e+05, step size -5.815e-05 new alpha -2.465e-03
# old alpha -2.465e-03, df 3.613e-01, ddf -2.862e+05, step size -1.262e-06 new alpha -2.464e-03
# old alpha -2.464e-03, df 2.086e-04, ddf -2.859e+05, step size -7.298e-10 new alpha -2.464e-03
# rtol hit
# block 46 slope 0.004730051001713364 pred slope 0.0024637811350394687
# old alpha -4.467e-03, df -8.386e+01, ddf 1.127e+04, step size -7.441e-03 new alpha 2.974e-03
# old alpha 2.974e-03, df 2.221e+02, ddf -8.497e+05, step size -2.614e-04 new alpha 3.235e-03
# old alpha 3.235e-03, df -8.593e+01, ddf -1.463e+06, step size 5.874e-05 new alpha 3.177e-03
# old alpha 3.177e-03, df -3.219e+00, ddf -1.350e+06, step size 2.384e-06 new alpha 3.174e-03
# old alpha 3.174e-03, df -5.888e-03, ddf -1.345e+06, step size 4.377e-09 new alpha 3.174e-03
# rtol hit
# block 47 slope 0.0051565720797133495 pred slope -0.0031741806890775597
# old alpha 0.000e+00, df 3.884e+01, ddf 6.335e+05, step size 6.131e-05 new alpha -6.131e-05
# old alpha -6.131e-05, df 2.474e-01, ddf 6.240e+05, step size 3.966e-07 new alpha -6.171e-05
# old alpha -6.171e-05, df 1.752e-05, ddf 6.239e+05, step size 2.809e-11 new alpha -6.171e-05
# rtol hit
# block 48 slope 0.0033689416952593916 pred slope 6.171038726591228e-05
# old alpha -2.233e-03, df -1.412e-01, ddf 1.975e+05, step size -7.151e-07 new alpha -2.233e-03
# old alpha -2.233e-03, df -1.054e-04, ddf 1.972e+05, step size -5.346e-10 new alpha -2.233e-03
# rtol hit
# block 49 slope -4.8779698349112596e-05 pred slope 0.0022326540269486514
# old alpha -6.700e-03, df 7.106e+01, ddf -1.967e+05, step size -3.613e-04 new alpha -6.339e-03
# old alpha -6.339e-03, df -5.871e+00, ddf -2.049e+05, step size 2.866e-05 new alpha -6.367e-03
# old alpha -6.367e-03, df 6.765e-02, ddf -2.094e+05, step size -3.230e-07 new alpha -6.367e-03
# rtol hit
# block 50 slope 0.006609035364262074 pred slope 0.006367160938202988
# old alpha -2.233e-03, df -1.076e+01, ddf -1.232e+05, step size 8.727e-05 new alpha -2.321e-03
# old alpha -2.321e-03, df -1.830e+00, ddf -8.209e+04, step size 2.229e-05 new alpha -2.343e-03
# old alpha -2.343e-03, df -1.087e-01, ddf -7.240e+04, step size 1.501e-06 new alpha -2.344e-03
# old alpha -2.344e-03, df -4.800e-04, ddf -7.176e+04, step size 6.689e-09 new alpha -2.344e-03
# rtol hit
# block 51 slope 0.0028683756209302936 pred slope 0.0023444457404851035
# old alpha 0.000e+00, df -1.441e+03, ddf 5.410e+05, step size -2.664e-03 new alpha 2.664e-03
# old alpha 2.664e-03, df 6.446e+02, ddf -1.021e+06, step size -6.316e-04 new alpha 3.295e-03
# old alpha 3.295e-03, df 1.470e+02, ddf -4.856e+05, step size -3.028e-04 new alpha 3.598e-03
# old alpha 3.598e-03, df 4.300e+01, ddf -2.149e+05, step size -2.001e-04 new alpha 3.798e-03
# old alpha 3.798e-03, df 1.342e+01, ddf -8.850e+04, step size -1.517e-04 new alpha 3.950e-03
# old alpha 3.950e-03, df 5.254e+00, ddf -2.348e+04, step size -2.237e-04 new alpha 4.174e-03
# old alpha 4.174e-03, df 6.850e+00, ddf 3.024e+04, step size 2.265e-04 new alpha 3.947e-03
# old alpha 3.947e-03, df 5.320e+00, ddf -2.444e+04, step size -2.177e-04 new alpha 4.165e-03
# old alpha 4.165e-03, df 6.589e+00, ddf 2.893e+04, step size 2.277e-04 new alpha 3.937e-03
# old alpha 3.937e-03, df 5.584e+00, ddf -2.800e+04, step size -1.994e-04 new alpha 4.137e-03
# Max iterations, unsuccessful.
# block 52 slope 0.0007816439560566741 pred slope -0.0041365235770611745
# old alpha -4.467e-03, df -8.747e+00, ddf -6.603e+04, step size 1.325e-04 new alpha -4.599e-03
# old alpha -4.599e-03, df -9.822e-01, ddf -4.982e+04, step size 1.972e-05 new alpha -4.619e-03
# old alpha -4.619e-03, df -3.003e-02, ddf -4.675e+04, step size 6.424e-07 new alpha -4.620e-03
# old alpha -4.620e-03, df -3.290e-05, ddf -4.664e+04, step size 7.054e-10 new alpha -4.620e-03
# rtol hit
# block 53 slope 0.007818050101311574 pred slope 0.004619564610080591
# old alpha -4.467e-03, df -7.330e+01, ddf -3.378e+05, step size 2.170e-04 new alpha -4.684e-03
# old alpha -4.684e-03, df 5.916e-01, ddf -3.298e+05, step size -1.794e-06 new alpha -4.682e-03
# old alpha -4.682e-03, df -3.492e-04, ddf -3.302e+05, step size 1.058e-09 new alpha -4.682e-03
# rtol hit
# block 54 slope 0.005066646642668759 pred slope 0.004681959825937643
# old alpha -4.467e-03, df 2.872e+01, ddf 1.097e+05, step size 2.619e-04 new alpha -4.729e-03
# old alpha -4.729e-03, df -4.452e+00, ddf 1.391e+05, step size -3.202e-05 new alpha -4.697e-03
# old alpha -4.697e-03, df -3.048e-02, ddf 1.371e+05, step size -2.224e-07 new alpha -4.696e-03
# rtol hit
# block 55 slope 0.004910049947818857 pred slope 0.004696402233520679
# old alpha -4.467e-03, df 2.614e+01, ddf 2.160e+04, step size 1.210e-03 new alpha -5.677e-03
# old alpha -5.677e-03, df -2.020e+01, ddf 5.220e+04, step size -3.871e-04 new alpha -5.290e-03
# old alpha -5.290e-03, df -3.550e-01, ddf 4.696e+04, step size -7.559e-06 new alpha -5.282e-03
# old alpha -5.282e-03, df -1.020e-03, ddf 4.669e+04, step size -2.183e-08 new alpha -5.282e-03
# rtol hit
# block 56 slope 0.004332171811355509 pred slope 0.005282207901807073
# old alpha -2.233e-03, df -1.687e+01, ddf 6.253e+04, step size -2.698e-04 new alpha -1.964e-03
# old alpha -1.964e-03, df -1.855e+00, ddf 3.797e+04, step size -4.885e-05 new alpha -1.915e-03
# old alpha -1.915e-03, df -2.643e-01, ddf 2.684e+04, step size -9.846e-06 new alpha -1.905e-03
# old alpha -1.905e-03, df -1.208e-02, ddf 2.437e+04, step size -4.955e-07 new alpha -1.904e-03
# old alpha -1.904e-03, df -3.120e-05, ddf 2.425e+04, step size -1.287e-09 new alpha -1.904e-03
# rtol hit
# block 57 slope 0.0029662865108843082 pred slope 0.0019044164959935988
# old alpha -6.700e-03, df -3.148e+01, ddf -5.152e+04, step size 6.110e-04 new alpha -7.311e-03
# old alpha -7.311e-03, df 2.012e+01, ddf -8.428e+04, step size -2.387e-04 new alpha -7.072e-03
# old alpha -7.072e-03, df -2.006e+00, ddf -9.569e+04, step size 2.097e-05 new alpha -7.093e-03
# old alpha -7.093e-03, df 3.745e-03, ddf -9.600e+04, step size -3.901e-08 new alpha -7.093e-03
# rtol hit
# block 58 slope 0.006143946137210776 pred slope 0.007093303876757683
# old alpha -4.467e-03, df 1.125e+02, ddf -2.369e+04, step size -4.746e-03 new alpha 2.797e-04
# old alpha 2.797e-04, df 1.070e+02, ddf 1.269e+05, step size 8.427e-04 new alpha -5.630e-04
# old alpha -5.630e-04, df -8.410e+01, ddf 1.740e+05, step size -4.832e-04 new alpha -7.980e-05
# old alpha -7.980e-05, df 3.280e+01, ddf 2.608e+05, step size 1.258e-04 new alpha -2.056e-04
# old alpha -2.056e-04, df -6.775e-01, ddf 2.677e+05, step size -2.530e-06 new alpha -2.031e-04
# old alpha -2.031e-04, df 1.068e-04, ddf 2.678e+05, step size 3.989e-10 new alpha -2.031e-04
# rtol hit
# block 59 slope 0.005267728014254889 pred slope 0.00020307185375673312
# old alpha -4.467e-03, df -8.624e+01, ddf -1.634e+04, step size 5.277e-03 new alpha -9.744e-03
# old alpha -9.744e-03, df 1.043e+01, ddf -1.878e+04, step size -5.551e-04 new alpha -9.189e-03
# old alpha -9.189e-03, df -1.350e+00, ddf -2.994e+04, step size 4.508e-05 new alpha -9.234e-03
# old alpha -9.234e-03, df -5.738e-02, ddf -2.745e+04, step size 2.091e-06 new alpha -9.236e-03
# old alpha -9.236e-03, df -1.134e-04, ddf -2.734e+04, step size 4.147e-09 new alpha -9.236e-03
# rtol hit
# block 60 slope 0.005250250013459464 pred slope 0.009236308464435364
# old alpha 0.000e+00, df -1.064e+03, ddf 6.309e+05, step size -1.686e-03 new alpha 1.686e-03
# old alpha 1.686e-03, df 1.294e+03, ddf -2.246e+05, step size -5.762e-03 new alpha 7.449e-03
# old alpha 7.449e-03, df 1.634e+02, ddf 2.471e+05, step size 6.616e-04 new alpha 6.787e-03
# old alpha 6.787e-03, df -1.588e+02, ddf 5.525e+05, step size -2.874e-04 new alpha 7.074e-03
# old alpha 7.074e-03, df 6.473e+00, ddf 5.533e+05, step size 1.170e-05 new alpha 7.063e-03
# old alpha 7.063e-03, df -2.926e-02, ddf 5.582e+05, step size -5.242e-08 new alpha 7.063e-03
# rtol hit
# block 61 slope 0.0006365877390972275 pred slope -0.007062706695220108
# old alpha -2.233e-03, df -1.232e+02, ddf -7.013e+03, step size 1.757e-02 new alpha -1.980e-02
# old alpha -1.980e-02, df 4.224e+00, ddf 1.357e+04, step size 3.114e-04 new alpha -2.012e-02
# old alpha -2.012e-02, df 2.181e+00, ddf -2.209e+03, step size -9.875e-04 new alpha -1.913e-02
# old alpha -1.913e-02, df 6.193e+00, ddf -2.724e+04, step size -2.273e-04 new alpha -1.890e-02
# old alpha -1.890e-02, df -3.421e+00, ddf -5.684e+04, step size 6.018e-05 new alpha -1.896e-02
# old alpha -1.896e-02, df -2.213e-01, ddf -4.939e+04, step size 4.479e-06 new alpha -1.897e-02
# old alpha -1.897e-02, df -1.286e-03, ddf -4.882e+04, step size 2.634e-08 new alpha -1.897e-02
# rtol hit
# block 62 slope 0.0013581931997583509 pred slope 0.01896561079701971
# old alpha -4.467e-03, df 9.133e+01, ddf 2.286e+05, step size 3.994e-04 new alpha -4.866e-03
# old alpha -4.866e-03, df -1.465e+01, ddf 2.643e+05, step size -5.545e-05 new alpha -4.811e-03
# old alpha -4.811e-03, df 2.482e-01, ddf 2.726e+05, step size 9.105e-07 new alpha -4.812e-03
# old alpha -4.812e-03, df 4.767e-05, ddf 2.725e+05, step size 1.750e-10 new alpha -4.812e-03
# rtol hit
# block 63 slope 0.0035055014241112694 pred slope 0.004811634527555317
# old alpha -4.467e-03, df 2.635e+01, ddf 1.278e+05, step size 2.061e-04 new alpha -4.673e-03
# old alpha -4.673e-03, df -6.374e-01, ddf 1.300e+05, step size -4.905e-06 new alpha -4.668e-03
# old alpha -4.668e-03, df 5.624e-04, ddf 1.302e+05, step size 4.321e-09 new alpha -4.668e-03
# rtol hit
# block 64 slope 0.0038325931866499416 pred slope 0.004667986555264206
# old alpha 1.831e-01, df 7.070e+01, ddf 2.269e+04, step size 3.116e-03 new alpha 1.800e-01
# old alpha 1.800e-01, df -6.644e+00, ddf -6.499e+04, step size 1.022e-04 new alpha 1.799e-01
# old alpha 1.799e-01, df 3.386e-01, ddf -7.162e+04, step size -4.728e-06 new alpha 1.799e-01
# rtol hit
# block 65 slope 0.0015085322609459714 pred slope -0.17992300235264277
# old alpha -4.467e-03, df -1.121e+02, ddf -1.779e+05, step size 6.303e-04 new alpha -5.097e-03
# old alpha -5.097e-03, df 1.732e+01, ddf -1.891e+05, step size -9.160e-05 new alpha -5.005e-03
# old alpha -5.005e-03, df -7.315e-01, ddf -2.042e+05, step size 3.583e-06 new alpha -5.009e-03
# old alpha -5.009e-03, df -8.594e-04, ddf -2.037e+05, step size 4.220e-09 new alpha -5.009e-03
# rtol hit
# block 66 slope 0.003486394809733188 pred slope 0.005008997866066253
# old alpha -4.467e-03, df 1.486e+01, ddf -2.356e+05, step size -6.310e-05 new alpha -4.404e-03
# old alpha -4.404e-03, df -1.568e-01, ddf -2.397e+05, step size 6.539e-07 new alpha -4.404e-03
# old alpha -4.404e-03, df -6.240e-06, ddf -2.397e+05, step size 2.603e-11 new alpha -4.404e-03
# rtol hit
# block 67 slope 0.0012439214766666378 pred slope 0.004404297133498775
# old alpha 0.000e+00, df 3.601e+02, ddf 1.633e+05, step size 2.205e-03 new alpha -2.205e-03
# old alpha -2.205e-03, df -3.970e+02, ddf -3.109e+05, step size 1.277e-03 new alpha -3.483e-03
# old alpha -3.483e-03, df 7.695e+01, ddf -8.377e+04, step size -9.186e-04 new alpha -2.564e-03
# old alpha -2.564e-03, df -2.495e+02, ddf -4.791e+05, step size 5.207e-04 new alpha -3.085e-03
# old alpha -3.085e-03, df -1.349e+01, ddf -3.603e+05, step size 3.745e-05 new alpha -3.122e-03
# old alpha -3.122e-03, df -4.124e-01, ddf -3.381e+05, step size 1.220e-06 new alpha -3.123e-03
# old alpha -3.123e-03, df -4.549e-04, ddf -3.373e+05, step size 1.349e-09 new alpha -3.123e-03
# rtol hit
# block 68 slope -0.0004901092992734805 pred slope 0.003123366718951604
# old alpha 4.467e-03, df -1.805e+00, ddf -8.123e+03, step size 2.222e-04 new alpha 4.245e-03
# old alpha 4.245e-03, df 7.348e-01, ddf -1.491e+04, step size -4.929e-05 new alpha 4.294e-03
# old alpha 4.294e-03, df 3.974e-02, ddf -1.331e+04, step size -2.986e-06 new alpha 4.297e-03
# old alpha 4.297e-03, df 1.417e-04, ddf -1.321e+04, step size -1.072e-08 new alpha 4.297e-03
# rtol hit
# block 69 slope -0.001472912681975196 pred slope -0.004296821685407545
# old alpha -2.233e-03, df 9.566e+01, ddf -2.730e+05, step size -3.504e-04 new alpha -1.883e-03
# old alpha -1.883e-03, df -4.397e+01, ddf -4.809e+05, step size 9.144e-05 new alpha -1.974e-03
# old alpha -1.974e-03, df -1.094e+00, ddf -4.532e+05, step size 2.414e-06 new alpha -1.977e-03
# old alpha -1.977e-03, df -1.239e-03, ddf -4.522e+05, step size 2.741e-09 new alpha -1.977e-03
# rtol hit
# block 70 slope 0.0026142362557437723 pred slope 0.001976805526238079
# old alpha 0.000e+00, df 8.208e+02, ddf 2.519e+05, step size 3.259e-03 new alpha -3.259e-03
# old alpha -3.259e-03, df 2.798e+02, ddf -1.923e+05, step size -1.455e-03 new alpha -1.803e-03
# old alpha -1.803e-03, df -1.064e+03, ddf -1.942e+05, step size 5.478e-03 new alpha -7.282e-03
# old alpha -7.282e-03, df -5.525e+01, ddf -6.253e+04, step size 8.836e-04 new alpha -8.165e-03
# old alpha -8.165e-03, df 3.487e+01, ddf 2.520e+03, step size 1.384e-02 new alpha -2.200e-02
# old alpha -2.200e-02, df -3.699e+00, ddf 3.372e+04, step size -1.097e-04 new alpha -2.189e-02
# old alpha -2.189e-02, df -1.302e-01, ddf 3.126e+04, step size -4.165e-06 new alpha -2.189e-02
# old alpha -2.189e-02, df -2.111e-04, ddf 3.116e+04, step size -6.776e-09 new alpha -2.189e-02
# rtol hit
# block 71 slope -0.0007509411324038625 pred slope 0.021890095660463443
# old alpha -2.233e-03, df 1.023e+02, ddf 2.448e+05, step size 4.177e-04 new alpha -2.651e-03
# old alpha -2.651e-03, df -1.698e+01, ddf 2.799e+05, step size -6.066e-05 new alpha -2.590e-03
# old alpha -2.590e-03, df 3.705e-01, ddf 2.914e+05, step size 1.272e-06 new alpha -2.592e-03
# old alpha -2.592e-03, df 1.202e-04, ddf 2.912e+05, step size 4.127e-10 new alpha -2.592e-03
# rtol hit
# block 72 slope 0.0033404075308140985 pred slope 0.0025916583253338794
# old alpha -2.233e-03, df -1.310e+02, ddf 2.769e+03, step size -4.731e-02 new alpha 4.507e-02
# old alpha 4.507e-02, df -8.370e+01, ddf 6.817e+04, step size -1.228e-03 new alpha 4.630e-02
# old alpha 4.630e-02, df 3.515e+01, ddf 5.653e+04, step size 6.217e-04 new alpha 4.568e-02
# old alpha 4.568e-02, df -2.199e+01, ddf 1.154e+05, step size -1.905e-04 new alpha 4.587e-02
# old alpha 4.587e-02, df -7.565e-01, ddf 1.057e+05, step size -7.154e-06 new alpha 4.588e-02
# old alpha 4.588e-02, df -1.973e-03, ddf 1.052e+05, step size -1.876e-08 new alpha 4.588e-02
# rtol hit
# block 73 slope 0.001992021958128905 pred slope -0.045876610744981595
# old alpha 8.933e-03, df 2.745e+02, ddf -4.238e+05, step size -6.477e-04 new alpha 9.581e-03
# old alpha 9.581e-03, df -4.379e+01, ddf -3.967e+05, step size 1.104e-04 new alpha 9.471e-03
# old alpha 9.471e-03, df 3.997e+00, ddf -4.659e+05, step size -8.580e-06 new alpha 9.479e-03
# old alpha 9.479e-03, df 1.987e-02, ddf -4.612e+05, step size -4.308e-08 new alpha 9.479e-03
# rtol hit
# block 74 slope 0.008150143139090146 pred slope -0.009479399108438383
# old alpha 6.477e-02, df -1.200e+02, ddf -3.866e+04, step size 3.105e-03 new alpha 6.166e-02
# old alpha 6.166e-02, df 5.840e+01, ddf -1.719e+04, step size -3.398e-03 new alpha 6.506e-02
# old alpha 6.506e-02, df -1.099e+02, ddf 1.084e+05, step size -1.014e-03 new alpha 6.607e-02
# old alpha 6.607e-02, df 9.869e+01, ddf 1.215e+05, step size 8.124e-04 new alpha 6.526e-02
# old alpha 6.526e-02, df -7.893e+01, ddf 1.949e+05, step size -4.050e-04 new alpha 6.567e-02
# old alpha 6.567e-02, df 1.768e+01, ddf 2.505e+05, step size 7.055e-05 new alpha 6.560e-02
# old alpha 6.560e-02, df -1.887e-01, ddf 2.549e+05, step size -7.404e-07 new alpha 6.560e-02
# rtol hit
# block 75 slope 0.0030777647274353626 pred slope -0.0655969862158678
# old alpha -2.233e-03, df -3.301e+01, ddf -1.706e+05, step size 1.935e-04 new alpha -2.427e-03
# old alpha -2.427e-03, df -1.745e+00, ddf -1.442e+05, step size 1.211e-05 new alpha -2.439e-03
# old alpha -2.439e-03, df -1.940e-02, ddf -1.410e+05, step size 1.376e-07 new alpha -2.439e-03
# rtol hit
# block 76 slope 0.001996277241915036 pred slope 0.0024391250009945698
# old alpha -4.467e-03, df -3.244e+01, ddf 2.889e+05, step size -1.123e-04 new alpha -4.354e-03
# old alpha -4.354e-03, df 1.200e+00, ddf 3.066e+05, step size 3.916e-06 new alpha -4.358e-03
# old alpha -4.358e-03, df 4.593e-04, ddf 3.063e+05, step size 1.499e-09 new alpha -4.358e-03
# rtol hit
# block 77 slope 0.0054236726683092274 pred slope 0.004358350299937599
# old alpha -1.340e-02, df -8.590e+01, ddf 1.045e+05, step size -8.222e-04 new alpha -1.258e-02
# old alpha -1.258e-02, df 5.154e+01, ddf 1.781e+05, step size 2.894e-04 new alpha -1.287e-02
# old alpha -1.287e-02, df -2.873e+00, ddf 1.897e+05, step size -1.515e-05 new alpha -1.285e-02
# old alpha -1.285e-02, df 4.718e-03, ddf 1.903e+05, step size 2.480e-08 new alpha -1.285e-02
# rtol hit
# block 78 slope 0.010099556523023929 pred slope 0.012852298736535924
# old alpha -6.700e-03, df 8.788e+00, ddf -2.732e+03, step size -3.217e-03 new alpha -3.483e-03
# old alpha -3.483e-03, df 6.282e+01, ddf 2.542e+04, step size 2.471e-03 new alpha -5.954e-03
# old alpha -5.954e-03, df -3.397e+00, ddf -2.070e+04, step size 1.641e-04 new alpha -6.118e-03
# old alpha -6.118e-03, df 5.959e-02, ddf -2.117e+04, step size -2.815e-06 new alpha -6.115e-03
# old alpha -6.115e-03, df -8.842e-06, ddf -2.117e+04, step size 4.176e-10 new alpha -6.115e-03
# rtol hit
# block 79 slope 0.011662433923613706 pred slope 0.00611542355406618
# old alpha -4.467e-03, df -1.566e+02, ddf -2.173e+05, step size 7.206e-04 new alpha -5.187e-03
# old alpha -5.187e-03, df -2.448e+00, ddf -1.097e+05, step size 2.231e-05 new alpha -5.210e-03
# old alpha -5.210e-03, df -1.096e-01, ddf -9.990e+04, step size 1.097e-06 new alpha -5.211e-03
# old alpha -5.211e-03, df -2.644e-04, ddf -9.942e+04, step size 2.660e-09 new alpha -5.211e-03
# rtol hit
# block 80 slope 0.0063750618065141675 pred slope 0.005210723902942429
# old alpha -2.233e-03, df 6.716e+00, ddf 4.720e+04, step size 1.423e-04 new alpha -2.376e-03
# old alpha -2.376e-03, df 4.072e+00, ddf -1.095e+04, step size -3.719e-04 new alpha -2.004e-03
# old alpha -2.004e-03, df 2.603e+01, ddf 1.120e+05, step size 2.324e-04 new alpha -2.236e-03
# old alpha -2.236e-03, df 6.588e+00, ddf 4.614e+04, step size 1.428e-04 new alpha -2.379e-03
# old alpha -2.379e-03, df 4.110e+00, ddf -1.231e+04, step size -3.339e-04 new alpha -2.045e-03
# old alpha -2.045e-03, df 2.156e+01, ddf 1.048e+05, step size 2.058e-04 new alpha -2.251e-03
# old alpha -2.251e-03, df 5.954e+00, ddf 4.047e+04, step size 1.471e-04 new alpha -2.398e-03
# old alpha -2.398e-03, df 4.420e+00, ddf -2.030e+04, step size -2.177e-04 new alpha -2.180e-03
# old alpha -2.180e-03, df 9.755e+00, ddf 6.666e+04, step size 1.463e-04 new alpha -2.326e-03
# old alpha -2.326e-03, df 4.043e+00, ddf 9.701e+03, step size 4.167e-04 new alpha -2.743e-03
# Max iterations, unsuccessful.
# block 81 slope 0.0013972377256688735 pred slope 0.0027431930717486414
# old alpha 5.449e-01, df 2.630e+01, ddf -5.552e+04, step size -4.738e-04 new alpha 5.454e-01
# old alpha 5.454e-01, df -2.097e+01, ddf -1.305e+05, step size 1.607e-04 new alpha 5.453e-01
# old alpha 5.453e-01, df -1.044e+00, ddf -1.151e+05, step size 9.074e-06 new alpha 5.452e-01
# rtol hit
# block 82 slope 5.668053779971003e-05 pred slope -0.5452461896386481
# old alpha 0.000e+00, df -1.210e+02, ddf 3.350e+04, step size -3.612e-03 new alpha 3.612e-03
# old alpha 3.612e-03, df -1.978e+02, ddf 1.314e+06, step size -1.505e-04 new alpha 3.762e-03
# old alpha 3.762e-03, df 6.928e+00, ddf 1.383e+06, step size 5.010e-06 new alpha 3.757e-03
# old alpha 3.757e-03, df -4.353e-05, ddf 1.383e+06, step size -3.148e-11 new alpha 3.757e-03
# rtol hit
# block 83 slope 0.0008005958016719805 pred slope -0.0037574541462382454
# old alpha -6.700e-03, df 2.547e+02, ddf 2.711e+05, step size 9.396e-04 new alpha -7.640e-03
# old alpha -7.640e-03, df -1.642e+02, ddf 4.122e+05, step size -3.984e-04 new alpha -7.241e-03
# old alpha -7.241e-03, df 2.637e+01, ddf 5.081e+05, step size 5.189e-05 new alpha -7.293e-03
# old alpha -7.293e-03, df -2.998e-02, ddf 5.085e+05, step size -5.896e-08 new alpha -7.293e-03
# rtol hit
# block 84 slope 0.004503929584310202 pred slope 0.007293092509787799
# old alpha -6.700e-03, df -3.698e+01, ddf 5.041e+05, step size -7.336e-05 new alpha -6.627e-03
# old alpha -6.627e-03, df 5.525e-01, ddf 5.168e+05, step size 1.069e-06 new alpha -6.628e-03
# old alpha -6.628e-03, df 4.206e-05, ddf 5.167e+05, step size 8.140e-11 new alpha -6.628e-03
# rtol hit
# block 85 slope 0.0040271352617602205 pred slope 0.0066278161330180505
# old alpha 0.000e+00, df -4.808e+02, ddf 8.574e+05, step size -5.608e-04 new alpha 5.608e-04
# old alpha 5.608e-04, df 1.321e+02, ddf 1.105e+06, step size 1.196e-04 new alpha 4.412e-04
# old alpha 4.412e-04, df -4.139e+00, ddf 1.165e+06, step size -3.554e-06 new alpha 4.448e-04
# old alpha 4.448e-04, df -1.654e-03, ddf 1.164e+06, step size -1.421e-09 new alpha 4.448e-04
# rtol hit
# block 86 slope 0.0002418695450532999 pred slope -0.0004447661960639753
# old alpha -1.340e-02, df 1.100e+02, ddf 4.431e+05, step size 2.483e-04 new alpha -1.365e-02
# old alpha -1.365e-02, df -5.681e-01, ddf 4.217e+05, step size -1.347e-06 new alpha -1.365e-02
# rtol hit
# block 87 slope -0.005488523458593294 pred slope 0.013647201279110038
# old alpha 6.700e-03, df -2.026e+00, ddf 3.574e+04, step size -5.668e-05 new alpha 6.757e-03
# old alpha 6.757e-03, df 4.826e-02, ddf 3.734e+04, step size 1.292e-06 new alpha 6.755e-03
# old alpha 6.755e-03, df 1.906e-05, ddf 3.731e+04, step size 5.109e-10 new alpha 6.755e-03
# rtol hit
# block 88 slope -0.003017705620510622 pred slope -0.006755491887746687
# old alpha 4.467e-03, df -2.803e+01, ddf 3.783e+05, step size -7.410e-05 new alpha 4.541e-03
# old alpha 4.541e-03, df 4.330e-02, ddf 3.776e+05, step size 1.147e-07 new alpha 4.541e-03
# rtol hit
# block 89 slope -0.0034215978460653317 pred slope -0.004540726080457324
# old alpha 0.000e+00, df -1.621e+02, ddf 7.057e+05, step size -2.298e-04 new alpha 2.298e-04
# old alpha 2.298e-04, df 6.335e+00, ddf 7.366e+05, step size 8.600e-06 new alpha 2.212e-04
# old alpha 2.212e-04, df -6.661e-03, ddf 7.381e+05, step size -9.024e-09 new alpha 2.212e-04
# rtol hit
# block 90 slope 0.0030138298572184394 pred slope -0.0002211790222472601
# old alpha 0.000e+00, df 6.135e+02, ddf 7.846e+05, step size 7.819e-04 new alpha -7.819e-04
# old alpha -7.819e-04, df -2.687e+02, ddf 1.031e+06, step size -2.605e-04 new alpha -5.214e-04
# old alpha -5.214e-04, df 3.347e+01, ddf 1.244e+06, step size 2.690e-05 new alpha -5.483e-04
# old alpha -5.483e-04, df 1.170e-01, ddf 1.235e+06, step size 9.474e-08 new alpha -5.484e-04
# old alpha -5.484e-04, df 1.807e-06, ddf 1.235e+06, step size 1.463e-12 new alpha -5.484e-04
# rtol hit
# block 91 slope -0.0006804895697269457 pred slope 0.0005484383729555963
# old alpha -2.233e-03, df -1.233e+01, ddf -2.843e+04, step size 4.336e-04 new alpha -2.667e-03
# old alpha -2.667e-03, df -1.700e+01, ddf 1.928e+04, step size -8.819e-04 new alpha -1.785e-03
# old alpha -1.785e-03, df -6.146e+01, ddf -1.903e+05, step size 3.230e-04 new alpha -2.108e-03
# old alpha -2.108e-03, df -1.851e+01, ddf -7.160e+04, step size 2.585e-04 new alpha -2.367e-03
# old alpha -2.367e-03, df -1.097e+01, ddf 5.565e+03, step size -1.971e-03 new alpha -3.958e-04
# old alpha -3.958e-04, df -5.045e+01, ddf 4.322e+05, step size -1.167e-04 new alpha -2.791e-04
# old alpha -2.791e-04, df 1.303e+00, ddf 4.485e+05, step size 2.907e-06 new alpha -2.820e-04
# old alpha -2.820e-04, df -7.954e-05, ddf 4.485e+05, step size -1.773e-10 new alpha -2.820e-04
# rtol hit
# block 92 slope 0.002589570278898133 pred slope 0.00028199803405066934
# old alpha -2.233e-03, df 5.549e+00, ddf 5.318e+04, step size 1.044e-04 new alpha -2.338e-03
# old alpha -2.338e-03, df 7.244e-01, ddf 4.020e+04, step size 1.802e-05 new alpha -2.356e-03
# old alpha -2.356e-03, df 1.531e-02, ddf 3.853e+04, step size 3.974e-07 new alpha -2.356e-03
# old alpha -2.356e-03, df 6.931e-06, ddf 3.850e+04, step size 1.801e-10 new alpha -2.356e-03
# rtol hit
# block 93 slope 0.004371417097218444 pred slope 0.002356139707204222
# old alpha -2.233e-03, df -1.552e+02, ddf -2.001e+05, step size 7.753e-04 new alpha -3.009e-03
# old alpha -3.009e-03, df 4.080e+01, ddf -2.573e+05, step size -1.586e-04 new alpha -2.850e-03
# old alpha -2.850e-03, df -1.176e+00, ddf -2.698e+05, step size 4.359e-06 new alpha -2.854e-03
# old alpha -2.854e-03, df -3.450e-04, ddf -2.696e+05, step size 1.280e-09 new alpha -2.854e-03
# rtol hit
# block 94 slope 0.0020087867510411666 pred slope 0.002854454117027201
# old alpha 0.000e+00, df -1.075e+03, ddf -5.415e+05, step size 1.986e-03 new alpha -1.986e-03
# old alpha -1.986e-03, df 1.225e+02, ddf 2.844e+05, step size 4.308e-04 new alpha -2.417e-03
# old alpha -2.417e-03, df -1.336e+01, ddf 2.979e+05, step size -4.485e-05 new alpha -2.372e-03
# old alpha -2.372e-03, df 2.567e-01, ddf 3.090e+05, step size 8.309e-07 new alpha -2.373e-03
# old alpha -2.373e-03, df 7.662e-05, ddf 3.088e+05, step size 2.482e-10 new alpha -2.373e-03
# rtol hit
# block 95 slope 0.0013337671567546935 pred slope 0.002372641697035112
# old alpha -4.824e-01, df 1.433e+01, ddf -1.357e+03, step size -1.056e-02 new alpha -4.718e-01
# old alpha -4.718e-01, df 2.528e+01, ddf 9.617e+04, step size 2.629e-04 new alpha -4.721e-01
# old alpha -4.721e-01, df 9.065e-01, ddf 8.483e+04, step size 1.069e-05 new alpha -4.721e-01
# rtol hit
# block 96 slope -0.0017497129605482586 pred slope 0.4721226735243052
# old alpha 0.000e+00, df -7.204e+02, ddf 1.293e+06, step size -5.569e-04 new alpha 5.569e-04
# old alpha 5.569e-04, df 1.773e+02, ddf 1.662e+06, step size 1.067e-04 new alpha 4.503e-04
# old alpha 4.503e-04, df -3.461e+00, ddf 1.717e+06, step size -2.015e-06 new alpha 4.523e-04
# old alpha 4.523e-04, df -4.963e-04, ddf 1.717e+06, step size -2.891e-10 new alpha 4.523e-04
# rtol hit
# block 97 slope 0.00027494594792219394 pred slope -0.0004523088751398302
# old alpha 4.467e-03, df 2.529e+02, ddf 2.500e+05, step size 1.012e-03 new alpha 3.455e-03
# old alpha 3.455e-03, df -3.174e+02, ddf 3.963e+05, step size -8.007e-04 new alpha 4.256e-03
# old alpha 4.256e-03, df 1.736e+02, ddf 4.933e+05, step size 3.520e-04 new alpha 3.904e-03
# old alpha 3.904e-03, df -4.648e+01, ddf 7.015e+05, step size -6.626e-05 new alpha 3.970e-03
# old alpha 3.970e-03, df -3.191e-01, ddf 6.895e+05, step size -4.629e-07 new alpha 3.970e-03
# old alpha 3.970e-03, df -3.100e-05, ddf 6.894e+05, step size -4.497e-11 new alpha 3.970e-03
# rtol hit
# block 98 slope -0.001456143587477515 pred slope -0.003970358943498359
# old alpha 0.000e+00, df -4.997e+01, ddf 6.815e+05, step size -7.333e-05 new alpha 7.333e-05
# old alpha 7.333e-05, df -9.372e-01, ddf 6.543e+05, step size -1.432e-06 new alpha 7.476e-05
# old alpha 7.476e-05, df -4.489e-04, ddf 6.537e+05, step size -6.867e-10 new alpha 7.476e-05
# rtol hit
# block 99 slope -1.997372847628182e-05 pred slope -7.475886206238077e-05
# /tmp/ipykernel_1644559/1410663048.py:25: RuntimeWarning: divide by zero encountered in scalar divide
#   if np.abs((alpha2-alpha)/alpha) < rtol:

# %%
plt.plot(-fit_delta)
plt.plot(actual_delta) #this is with poor S/N and LOT of "flicker". We'll have less flicker and more S/N

# %%
plt.plot(np.diff(fit_delta/4096)[:9])

# %%
pred_drift=np.zeros(nblocks*blocksize)
t = np.arange(blocksize)
for i in range(nblocks):
    pred_drift[i*blocksize : (i+1)*blocksize] = pred_drift[i*blocksize-1] - 2*np.pi*1834*t*fit_delta[i]/4096

# %%
st=0
en=None
plt.plot(pred_drift[st:en])

# %%
st=7000
en=7500
plt.plot(delays[st:en])
